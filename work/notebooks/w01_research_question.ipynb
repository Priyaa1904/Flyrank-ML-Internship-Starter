# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyaa1904/Flyrank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Priyaa1904/Flyrank-ML-Internship-Starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My lane is Content Refresh. I want to focus on prioritizing content pages that may need a refresh. I chose this lane because the dataset contains search-performance, engagement, and trend signals that can help distinguish pages that are declining from pages that are stable or improving. I want to investigate whether these signals can support a practical priority list for deciding which pages an editor should review first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision is which content pages should be reviewed or refreshed first. An SEO or content team would use the recommendation to prioritize a limited number of pages for review. A wrong recommendation can waste editing time on a page that does not need attention, while missing a genuinely declining page can delay a useful refresh. The goal is therefore to provide a ranked, decision-support list rather than an automatic final decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 283, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 283 (delta 112), reused 83 (delta 83), pack-reused 138 (from 1)
# Receiving objects: 100% (283/283), 1.85 MiB | 5.02 MiB/s, done.
# Resolving deltas: 100% (153/153), done.

# %%
# %cd flyrank-ml-internship-starter
# Out:
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %% [markdown]
# The starter dataset contains 30,000 content pages. Of these, 16,262 pages have a `down` trend, which is about 54.2% of the dataset. The average CTR is 0.324 for pages with a `down` trend compared with 0.566 for pages with an `up` trend. These observed differences make it worth investigating whether search-performance and engagement signals can help prioritize pages for content review.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))

print("\nTrend distribution:")
print(df["trend_direction"].value_counts())

print("\nAverage CTR by trend:")
print(df.groupby("trend_direction")["ctr"].mean().round(3))
# Out:
# Total pages: 30000
#
# Trend distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR by trend:
# trend_direction
# down      0.324
# flat      1.377
# new       1.297
# stable    0.517
# up        0.566
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My analysis can describe observed patterns and measured relationships in the dataset. It can provide directional evidence about which signals may be useful for prioritizing pages and can support a ranked list for content review. It cannot prove that one factor causes a page's performance to decline and it cannot predict or explain exactly how Google will rank a page. Any model I build should therefore be treated as decision-support rather than as causal proof or an automatic decision-maker.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
